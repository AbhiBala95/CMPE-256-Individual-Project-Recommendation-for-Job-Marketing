# %% [markdown]
# In this section of the codes, a collaborative recommendation system for a small subset of users and jobs is implemented by simulating the value of number of applications by similar users variable. The sparsity of the dataset is studied and alternating least square method is applied on the dataset to obtain the recommendation list of similar jobs applied by similar users.

# %%
import pandas as pd

# %%
collab_job=pd.read_csv('collab_job.csv')

# %%
collab_job
# Out:
#      user_id  job_id                                               name
# 0          1       1  Computer Software Developer (Predictive Modeling)
# 1          1       2                                   Python Developer
# 2          1       3                                   Python Developer
# 3          1       4                                     BMI Consultant
# 4          1       5                    Software Engineer - entry level
# 5          1       6                      Sr. ETL/Informatica Developer
# 6          1       7                     Analyst, Application Developer
# 7          1       8                                  Angular Developer
# 8          1       9  Services Information Developer Specialist--Pyt...
# 9          1      10                                  Software Engineer
# 10         1      11  Services Information Developer Specialist--Python
# 11         1      12                      Ansible Developer (BH6) (TF3)
# 12         1      13                                 Investment Analyst
# 13         1      14                                Dev Ops Engineer II
# 14         2       1  Computer Software Developer (Predictive Modeling)
# 15         2       2                                   Python Developer
# 16         2       3                                   Python Developer
# 17         2       4                                     BMI Consultant
# 18         2       5                    Software Engineer - entry level
# 19         2       6                      Sr. ETL/Informatica Developer
# 20         2       7                     Analyst, Application Developer
# 21         2       8                                  Angular Developer
# 22         2       9  Services Information Developer Specialist--Pyt...
# 23         2      10                                  Software Engineer
# 24         2      11  Services Information Developer Specialist--Python
# 25         2      12                      Ansible Developer (BH6) (TF3)
# 26         2      13                                 Investment Analyst
# 27         2      14                                Dev Ops Engineer II
# 28         2      15                                 Software Developer
# 29         3       1  Computer Software Developer (Predictive Modeling)
# ..       ...     ...                                                ...
# 135       12       1  Computer Software Developer (Predictive Modeling)
# 136       12       2                                   Python Developer
# 137       12       3                                   Python Developer
# 138       13       1  Computer Software Developer (Predictive Modeling)
# 139       13       2                                   Python Developer
# 140       13       3                                   Python Developer
# 141       13       4                                     BMI Consultant
# 142       13       5                    Software Engineer - entry level
# 143       13       6                      Sr. ETL/Informatica Developer
# 144       13       7                     Analyst, Application Developer
# 145       13       8                                  Angular Developer
# 146       13       9  Services Information Developer Specialist--Pyt...
# 147       13      10                                  Software Engineer
# 148       14       1  Computer Software Developer (Predictive Modeling)
# 149       14       2                                   Python Developer
# 150       14       3                                   Python Developer
# 151       14       4                                     BMI Consultant
# 152       14       5                    Software Engineer - entry level
# 153       14       6                      Sr. ETL/Informatica Developer
# 154       14       7                     Analyst, Application Developer
# 155       14       8                                  Angular Developer
# 156       14       9  Services Information Developer Specialist--Pyt...
# 157       15       1  Computer Software Developer (Predictive Modeling)
# 158       15       2                                   Python Developer
# 159       15       3                                   Python Developer
# 160       15       4                                     BMI Consultant
# 161       15       5                    Software Engineer - entry level
# 162       15       6                      Sr. ETL/Informatica Developer
# 163       15       7                     Analyst, Application Developer
# 164       15       8                                  Angular Developer
#
# [165 rows x 3 columns]

# %%
import numpy as np
collab_job['events'] = np.random.randint(1, 10, collab_job.shape[0])

# %%
collab_job
# Out:
#      user_id  job_id                                               name  \
# 0          1       1  Computer Software Developer (Predictive Modeling)
# 1          1       2                                   Python Developer
# 2          1       3                                   Python Developer
# 3          1       4                                     BMI Consultant
# 4          1       5                    Software Engineer - entry level
# 5          1       6                      Sr. ETL/Informatica Developer
# 6          1       7                     Analyst, Application Developer
# 7          1       8                                  Angular Developer
# 8          1       9  Services Information Developer Specialist--Pyt...
# 9          1      10                                  Software Engineer
# 10         1      11  Services Information Developer Specialist--Python
# 11         1      12                      Ansible Developer (BH6) (TF3)
# 12         1      13                                 Investment Analyst
# 13         1      14                                Dev Ops Engineer II
# 14         2       1  Computer Software Developer (Predictive Modeling)
# 15         2       2                                   Python Developer
# 16         2       3                                   Python Developer
# 17         2       4                                     BMI Consultant
# 18         2       5                    Software Engineer - entry level
# 19         2       6                      Sr. ETL/Informatica Developer
# 20         2       7                     Analyst, Application Developer
# 21         2       8                                  Angular Developer
# 22         2       9  Services Information Developer Specialist--Pyt...
# 23         2      10                                  Software Engineer
# 24         2      11  Services Information Developer Specialist--Python
# 25         2      12                      Ansible Developer (BH6) (TF3)
# 26         2      13                                 Investment Analyst
# 27         2      14                                Dev Ops Engineer II
# 28         2      15                                 Software Developer
# 29         3       1  Computer Software Developer (Predictive Modeling)
# ..       ...     ...                                                ...
# 135       12       1  Computer Software Developer (Predictive Modeling)
# 136       12       2                                   Python Developer
# 137       12       3                                   Python Developer
# 138       13       1  Computer Software Developer (Predictive Modeling)
# 139       13       2                                   Python Developer
# 140       13       3                                   Python Developer
# 141       13       4                                     BMI Consultant
# 142       13       5                    Software Engineer - entry level
# 143       13       6                      Sr. ETL/Informatica Developer
# 144       13       7                     Analyst, Application Developer
# 145       13       8                                  Angular Developer
# 146       13       9  Services Information Developer Specialist--Pyt...
# 147       13      10                                  Software Engineer
# 148       14       1  Computer Software Developer (Predictive Modeling)
# 149       14       2                                   Python Developer
# 150       14       3                                   Python Developer
# 151       14       4                                     BMI Consultant
# 152       14       5                    Software Engineer - entry level
# 153       14       6                      Sr. ETL/Informatica Developer
# 154       14       7                     Analyst, Application Developer
# 155       14       8                                  Angular Developer
# 156       14       9  Services Information Developer Specialist--Pyt...
# 157       15       1  Computer Software Developer (Predictive Modeling)
# 158       15       2                                   Python Developer
# 159       15       3                                   Python Developer
# 160       15       4                                     BMI Consultant
# 161       15       5                    Software Engineer - entry level
# 162       15       6                      Sr. ETL/Informatica Developer
# 163       15       7                     Analyst, Application Developer
# 164       15       8                                  Angular Developer
#
#      events
# 0         5
# 1         4
# 2         7
# 3         1
# 4         4
# 5         5
# 6         7
# 7         8
# 8         5
# 9         3
# 10        4
# 11        3
# 12        8
# 13        9
# 14        8
# 15        7
# 16        7
# 17        6
# 18        6
# 19        1
# 20        9
# 21        2
# 22        8
# 23        6
# 24        4
# 25        6
# 26        8
# 27        9
# 28        3
# 29        8
# ..      ...
# 135       6
# 136       6
# 137       6
# 138       2
# 139       1
# 140       1
# 141       2
# 142       7
# 143       9
# 144       4
# 145       8
# 146       6
# 147       5
# 148       6
# 149       3
# 150       2
# 151       6
# 152       8
# 153       7
# 154       7
# 155       3
# 156       7
# 157       9
# 158       6
# 159       8
# 160       5
# 161       6
# 162       3
# 163       9
# 164       9
#
# [165 rows x 4 columns]

# %%
from scipy import sparse
sparse_user_item = sparse.csr_matrix((collab_job['events'].astype(float), (collab_job['user_id'], collab_job['job_id'])))
print(sparse_user_item)
# Out:
#   (1, 1)	5.0
#   (1, 2)	4.0
#   (1, 3)	7.0
#   (1, 4)	1.0
#   (1, 5)	4.0
#   (1, 6)	5.0
#   (1, 7)	7.0
#   (1, 8)	8.0
#   (1, 9)	5.0
#   (1, 10)	3.0
#   (1, 11)	4.0
#   (1, 12)	3.0
#   (1, 13)	8.0
#   (1, 14)	9.0
#   (2, 1)	8.0
#   (2, 2)	7.0
#   (2, 3)	7.0
#   (2, 4)	6.0
#   (2, 5)	6.0
#   (2, 6)	1.0
#   (2, 7)	9.0
#   (2, 8)	2.0
#   (2, 9)	8.0
#   (2, 10)	6.0
#   (2, 11)	4.0
#   :	:
#   (13, 3)	1.0
#   (13, 4)	2.0
#   (13, 5)	7.0
#   (13, 6)	9.0
#   (13, 7)	4.0
#   (13, 8)	8.0
#   (13, 9)	6.0
#   (13, 10)	5.0
#   (14, 1)	6.0
#   (14, 2)	3.0
#   (14, 3)	2.0
#   (14, 4)	6.0
#   (14, 5)	8.0
#   (14, 6)	7.0
#   (14, 7)	7.0
#   (14, 8)	3.0
#   (14, 9)	7.0
#   (15, 1)	9.0
#   (15, 2)	6.0
#   (15, 3)	8.0
#   (15, 4)	5.0
#   (15, 5)	6.0
#   (15, 6)	3.0
#   (15, 7)	9.0
#   (15, 8)	9.0

# %%
# Number of possible interactions in the matrix
matrix_size = sparse_user_item.shape[0]*sparse_user_item.shape[1]

# Count of interactions
count_interactions = sparse_user_item.size

# Compute matrix sparsity
sparsity = 100*(1 - (float(count_interactions)/float(matrix_size)))

print(sparsity)
# Out:
# 61.80555555555556

# %%
import implicit
# Set parameters
confidence_coef = 15
factors = 60
regularization = 0.1
iterations = 100

# Initialize model
model = implicit.als.AlternatingLeastSquares(factors=factors, regularization=regularization, iterations=iterations)

# Fit model
model.fit((sparse_user_item.T*confidence_coef).astype('double'))

# Get user and item vectors from our trained model
user_vecs = model.user_factors
item_vecs = model.item_factors
# Out:
# WARNING:root:Intel MKL BLAS detected. Its highly recommend to set the environment variable 'export MKL_NUM_THREADS=1' to disable its internal multithreading
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %%
from sklearn.preprocessing import MinMaxScaler
# Get recommendations results

def recommend(user_id, sparse_user_item, user_vecs, item_vecs, num_items=10):
    user_interactions = sparse_user_item[user_id,:].toarray()
    user_interactions = user_interactions.reshape(-1) + 1
    user_interactions[user_interactions > 1] = 0
    rec_vector = user_vecs[user_id,:].dot(item_vecs.T)
    min_max = MinMaxScaler()
    rec_vector_scaled = min_max.fit_transform(rec_vector.reshape(-1,1))[:,0]
    recommend_vector = user_interactions * rec_vector_scaled
    #print(recommend_vector)
    item_idx = np.argsort(recommend_vector)[::-1][:num_items]
    job_rec_df=collab_job.iloc[item_idx]
    job_rec_df=job_rec_df.drop(['user_id', 'job_id', 'events'], axis=1)
    #return job_rec_df
    scores=[]
    for idx in item_idx:
        scores.append(recommend_vector[idx])
    job_rec_df['Scores']=scores
    return job_rec_df

# %%
user_id=12
recommendations = recommend(user_id, sparse_user_item, user_vecs, item_vecs)

print('APPLICATIONS HISTORY FOR USER : ' + str(user_id) + '\n')
print(collab_job[collab_job['user_id']==user_id][['name','events']])
print('\n RECOMMEND FOLLOWING JOBS \n')
print(recommendations)
# Out:
# APPLICATIONS HISTORY FOR USER : 12
#
#                                                   name  events
# 135  Computer Software Developer (Predictive Modeling)       6
# 136                                   Python Developer       6
# 137                                   Python Developer       6
#
#  RECOMMEND FOLLOWING JOBS
#
#                                                  name    Scores
# 5                       Sr. ETL/Informatica Developer  0.118293
# 4                     Software Engineer - entry level  0.108786
# 9                                   Software Engineer  0.033151
# 7                                   Angular Developer  0.028494
# 6                      Analyst, Application Developer  0.021730
# 8   Services Information Developer Specialist--Pyt...  0.020601
# 12                                 Investment Analyst  0.019206
# 15                                   Python Developer  0.018846
# 14  Computer Software Developer (Predictive Modeling)  0.018275
# 0   Computer Software Developer (Predictive Modeling)  0.016990
