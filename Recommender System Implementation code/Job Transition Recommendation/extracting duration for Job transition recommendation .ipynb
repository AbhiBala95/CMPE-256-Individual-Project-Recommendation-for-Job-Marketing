# %% [markdown]
# Extracting the experience duration for all the job postings in the user dataset for performing job transition recommendation

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
profiles = pd.read_excel('python_profiles1.xlsx')

# %%
profiles
# Out:
#                           Name  \
# 0                  Paul Garner
# 1            Bartosz Dziendzik
# 2                 Cal Paterson
# 3                 Danny Butler
# 4              Georgi Georgiev
# 5               Luca Romagnoli
# 6                Sandra Greiss
# 7           Pablo Chao Andrade
# 8                  Scott White
# 9             Lukasz Szczesiak
# 10                   Harish .N
# 11                    Keshav M
# 12          Iskandar Bakhtizin
# 13                    Isaac To
# 14            Anastasiia Konak
# 15              Nivedha Balaji
# 16               Michael Alber
# 17             Srinivas Murthy
# 18                   mounika s
# 19              Santhosh Kumar
# 20               Jeremy N Pitt
# 21                Peter Kadlot
# 22             Tiago Fernandes
# 23           Mohammad Abdullah
# 24                  Onur Yasar
# 25          Rubén García López
# 26              Kiran Kulkarni
# 27                 Vito Tardia
# 28                Julian Wyatt
# ...

# %%
profiles['Old Positions'] = profiles['Old Positions'].str.replace('[','')

# %%
profiles['Old Positions'] = profiles['Old Positions'].str.replace(']','')

# %%
profiles['Old Positions'] = profiles['Old Positions'].str.replace(r"[\"\']", '')

# %%
new = profiles["Old Positions"].str.split(",", expand = True)

# %%
new
# Out:
#                                                      0  \
# 0                           Freelance Python Developer
# 1                                     Python Developer
# 2                            Contract Python Developer
# 3                                                  NaN
# 4                                                  NaN
# 5                                           Supervisor
# 6                                       Data Scientist
# 7                                     Python Developer
# 8                  Python Developer / Django Developer
# 9                             Senior Software Engineer
# 10                                    Python Developer
# 11                                    Python Developer
# 12                                                 NaN
# 13                                  Software Developer
# 14                         Python Developer at Uniblue
# 15                             Python Developer Intern
# ...

# %%
new.columns=['Position1','Position2','Position3','Position4','Position5','Position6','Position7']

# %%
new
# Out:
#                                              Position1  \
# 0                           Freelance Python Developer
# 1                                     Python Developer
# 2                            Contract Python Developer
# 3                                                  NaN
# 4                                                  NaN
# 5                                           Supervisor
# 6                                       Data Scientist
# 7                                     Python Developer
# 8                  Python Developer / Django Developer
# 9                             Senior Software Engineer
# 10                                    Python Developer
# 11                                    Python Developer
# 12                                                 NaN
# 13                                  Software Developer
# 14                         Python Developer at Uniblue
# 15                             Python Developer Intern
# ...

# %%
profiles=pd.concat([profiles,new], axis=1)

# %%
profiles
# Out:
#                           Name  \
# 0                  Paul Garner
# 1            Bartosz Dziendzik
# 2                 Cal Paterson
# 3                 Danny Butler
# 4              Georgi Georgiev
# 5               Luca Romagnoli
# 6                Sandra Greiss
# 7           Pablo Chao Andrade
# 8                  Scott White
# 9             Lukasz Szczesiak
# 10                   Harish .N
# 11                    Keshav M
# 12          Iskandar Bakhtizin
# 13                    Isaac To
# 14            Anastasiia Konak
# 15              Nivedha Balaji
# 16               Michael Alber
# 17             Srinivas Murthy
# 18                   mounika s
# 19              Santhosh Kumar
# 20               Jeremy N Pitt
# 21                Peter Kadlot
# 22             Tiago Fernandes
# 23           Mohammad Abdullah
# 24                  Onur Yasar
# 25          Rubén García López
# 26              Kiran Kulkarni
# 27                 Vito Tardia
# 28                Julian Wyatt
# ...

# %%
profiles
# Out:
#                           Name  \
# 0                  Paul Garner
# 1            Bartosz Dziendzik
# 2                 Cal Paterson
# 3                 Danny Butler
# 4              Georgi Georgiev
# 5               Luca Romagnoli
# 6                Sandra Greiss
# 7           Pablo Chao Andrade
# 8                  Scott White
# 9             Lukasz Szczesiak
# 10                   Harish .N
# 11                    Keshav M
# 12          Iskandar Bakhtizin
# 13                    Isaac To
# 14            Anastasiia Konak
# 15              Nivedha Balaji
# 16               Michael Alber
# 17             Srinivas Murthy
# 18                   mounika s
# 19              Santhosh Kumar
# 20               Jeremy N Pitt
# 21                Peter Kadlot
# 22             Tiago Fernandes
# 23           Mohammad Abdullah
# 24                  Onur Yasar
# 25          Rubén García López
# 26              Kiran Kulkarni
# 27                 Vito Tardia
# 28                Julian Wyatt
# ...

# %%
import numpy as np
profiles.replace(to_replace=[None], value=np.nan, inplace=True)

# %%
profiles
# Out:
#                           Name  \
# 0                  Paul Garner
# 1            Bartosz Dziendzik
# 2                 Cal Paterson
# 3                 Danny Butler
# 4              Georgi Georgiev
# 5               Luca Romagnoli
# 6                Sandra Greiss
# 7           Pablo Chao Andrade
# 8                  Scott White
# 9             Lukasz Szczesiak
# 10                   Harish .N
# 11                    Keshav M
# 12          Iskandar Bakhtizin
# 13                    Isaac To
# 14            Anastasiia Konak
# 15              Nivedha Balaji
# 16               Michael Alber
# 17             Srinivas Murthy
# 18                   mounika s
# 19              Santhosh Kumar
# 20               Jeremy N Pitt
# 21                Peter Kadlot
# 22             Tiago Fernandes
# 23           Mohammad Abdullah
# 24                  Onur Yasar
# 25          Rubén García López
# 26              Kiran Kulkarni
# 27                 Vito Tardia
# 28                Julian Wyatt
# ...

# %%
profiles['Old Companies'] = profiles['Old Companies'].str.replace('[','')

# %%
profiles['Old Companies'] = profiles['Old Companies'].str.replace(']','')

# %%
profiles['Old Companies'] = profiles['Old Companies'].str.replace(r"[\"\']", '')

# %%
profiles
# Out:
#                           Name  \
# 0                  Paul Garner
# 1            Bartosz Dziendzik
# 2                 Cal Paterson
# 3                 Danny Butler
# 4              Georgi Georgiev
# 5               Luca Romagnoli
# 6                Sandra Greiss
# 7           Pablo Chao Andrade
# 8                  Scott White
# 9             Lukasz Szczesiak
# 10                   Harish .N
# 11                    Keshav M
# 12          Iskandar Bakhtizin
# 13                    Isaac To
# 14            Anastasiia Konak
# 15              Nivedha Balaji
# 16               Michael Alber
# 17             Srinivas Murthy
# 18                   mounika s
# 19              Santhosh Kumar
# 20               Jeremy N Pitt
# 21                Peter Kadlot
# 22             Tiago Fernandes
# 23           Mohammad Abdullah
# 24                  Onur Yasar
# 25          Rubén García López
# 26              Kiran Kulkarni
# 27                 Vito Tardia
# 28                Julian Wyatt
# ...

# %%
profiles['Number of years'] = profiles['Number of years'].str.replace('[','')

# %%
profiles['Number of years'] = profiles['Number of years'].str.replace(']','')

# %%
profiles['Number of years'] = profiles['Number of years'].str.replace(r"[\"\']", '')

# %%
profiles
# Out:
#                           Name  \
# 0                  Paul Garner
# 1            Bartosz Dziendzik
# 2                 Cal Paterson
# 3                 Danny Butler
# 4              Georgi Georgiev
# 5               Luca Romagnoli
# 6                Sandra Greiss
# 7           Pablo Chao Andrade
# 8                  Scott White
# 9             Lukasz Szczesiak
# 10                   Harish .N
# 11                    Keshav M
# 12          Iskandar Bakhtizin
# 13                    Isaac To
# 14            Anastasiia Konak
# 15              Nivedha Balaji
# 16               Michael Alber
# 17             Srinivas Murthy
# 18                   mounika s
# 19              Santhosh Kumar
# 20               Jeremy N Pitt
# 21                Peter Kadlot
# 22             Tiago Fernandes
# 23           Mohammad Abdullah
# 24                  Onur Yasar
# 25          Rubén García López
# 26              Kiran Kulkarni
# 27                 Vito Tardia
# 28                Julian Wyatt
# ...

# %%
years = profiles["Number of years"].str.split(",", expand = True)

# %%
years
# Out:
#                 0             1                  2              3  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos          None               None           None
# 2           4 mos    1 yr 3 mos               None           None
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos          None               None           None
# 6      1 yr 7 mos          1 mo               None           None
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs               None           None
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years.columns=['exp1','exp2','exp3','exp4','exp5']

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos          None               None           None
# 2           4 mos    1 yr 3 mos               None           None
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos          None               None           None
# 6      1 yr 7 mos          1 mo               None           None
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs               None           None
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years.fillna(value=pd.np.nan, inplace=True)

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp1_months'] = years['exp1'].str.split('yr').str[1]

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp1_months']=years.exp1_months.str.extract('(\d+)')

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp2_months'] = years['exp2'].str.split('yr').str[1]

# %%
years['exp2_months']=years.exp2_months.str.extract('(\d+)')

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp3_months'] = years['exp3'].str.split('yr').str[1]

# %%
years['exp3_months']=years.exp3_months.str.extract('(\d+)')

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp4_months'] = years['exp4'].str.split('yr').str[1]

# %%
years['exp4_months']=years.exp4_months.str.extract('(\d+)')

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp5_months'] = years['exp5'].str.split('yr').str[1]

# %%
years['exp5_months']=years.exp5_months.str.extract('(\d+)')

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp1_years'] = years['exp1'].str.split('yr').str[0]

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp2_years'] = years['exp2'].str.split('yr').str[0]

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp1_years']=pd.np.where(years.exp1_years.str.contains("mo"), np.nan,years.exp1_years)

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp2_years']=pd.np.where(years.exp2_years.str.contains("mo"), np.nan,years.exp2_years)

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp3_years'] = years['exp3'].str.split('yr').str[0]

# %%
years['exp3_years']=pd.np.where(years.exp3_years.str.contains("mo"), np.nan,years.exp3_years)

# %%
years['exp3_years']=pd.np.where(years.exp3_years.str.contains("less"), "1",years.exp3_years)

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp4_years'] = years['exp4'].str.split('yr').str[0]

# %%
years['exp4_years']=pd.np.where(years.exp4_years.str.contains("mo"), np.nan,years.exp4_years)

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years['exp5_years'] = years['exp5'].str.split('yr').str[0]

# %%
years['exp5_years']=pd.np.where(years.exp5_years.str.contains("mo"), np.nan,years.exp5_years)

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos           NaN                NaN            NaN
# 2           4 mos    1 yr 3 mos                NaN            NaN
# 3             NaN           NaN                NaN            NaN
# 4             NaN           NaN                NaN            NaN
# 5     2 yrs 3 mos           NaN                NaN            NaN
# 6      1 yr 7 mos          1 mo                NaN            NaN
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                NaN            NaN
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12            NaN           NaN                NaN            NaN
# ...

# %%
years.fillna(0, inplace=True)

# %%
years.dtypes
# Out:
# exp1           object
# exp2           object
# exp3           object
# exp4           object
# exp5           object
# exp1_months    object
# exp2_months    object
# exp3_months    object
# exp4_months    object
# exp5_months    object
# exp1_years     object
# exp2_years     object
# exp3_years     object
# exp4_years     object
# exp5_years     object
# dtype: object

# %%
years['exp1_years']=years['exp1_years'].astype(str).astype(int)

# %%
years['exp2_years']=years['exp2_years'].astype(str).astype(int)

# %%
years['exp3_years']=years['exp3_years'].astype(str).astype(int)

# %%
years['exp4_years']=years['exp4_years'].astype(str).astype(int)

# %%
years['exp5_years']=years['exp5_years'].astype(str).astype(int)

# %%
years
# Out:
#              exp1          exp2               exp3           exp4  \
# 0     4 yrs 2 mos   4 yrs 6 mos              3 mos         10 mos
# 1          10 mos             0                  0              0
# 2           4 mos    1 yr 3 mos                  0              0
# 3               0             0                  0              0
# 4               0             0                  0              0
# 5     2 yrs 3 mos             0                  0              0
# 6      1 yr 7 mos          1 mo                  0              0
# 7      1 yr 7 mos   2 yrs 7 mos             12 mos     1 yr 2 mos
# 8     7 yrs 7 mos         4 yrs                  0              0
# 9           5 mos         6 mos        3 yrs 8 mos   3 yrs 11 mos
# 10         11 mos    1 yr 3 mos        1 yr 11 mos     1 yr 6 mos
# 11     2 yrs 1 mo          1 yr               1 yr    2 yrs 4 mos
# 12              0             0                  0              0
# ...

# %%
years.to_csv('duration.csv',index=False)
